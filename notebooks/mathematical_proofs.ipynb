# %% [markdown]
# # Excalibur-EXS: Mathematical Proofs and Cryptographic Analysis
#
# This notebook demonstrates the mathematical foundations of the Excalibur protocol.
#
# **Author**: Travis D. Jones
# **Date**: 2026-01-02
# **Version**: 2.0.0
